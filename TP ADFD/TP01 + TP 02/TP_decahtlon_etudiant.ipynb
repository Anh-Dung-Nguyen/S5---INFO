# %%
import pandas as pd
from sklearn import preprocessing
from sklearn import decomposition
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Chargement des données
# Récupérer sur moodle le fichier decathlon.csv. Ce jeu de données décrit les performances d'athlètes aux jeux olympiques à une compétition de décathlon. Il contient 41 lignes, chacune associée aux performances d'un athlète. Les 10 premières colonnes contiennent les résultats de l'athlète aux 10 épreuves (100m, saut en longueur, lancer de poids, saut en hauteur, 400m, 110m haies, saut à la perche, javelot et 1500m). Les trois dernières colonnes contiennent respectivement le rang de l'athlète lors de la compétition, son nombre de points et le nom de la compétition.
#
# ### Question 1
# Charger le jeu de données et afficher les premières lignes.

# %%
# Out:
# affichage des premières lignes du dataframe
#           100m  Long.jump  Shot.put  High.jump   400m  110m.hurdle  Discus  \
# SEBRLE   11.04       7.58     14.83       2.07  49.81        14.69   43.75
# CLAY     10.76       7.40     14.26       1.86  49.37        14.05   50.72
# KARPOV   11.02       7.30     14.77       2.04  48.37        14.09   48.95
# BERNARD  11.02       7.23     14.25       1.92  48.93        14.99   40.87
# YURKOV   11.34       7.09     15.19       2.10  50.42        15.31   46.26
#
#          Pole.vault  Javeline  1500m  Rank  Points Competition
# SEBRLE         5.02     63.19  291.7     1    8217    Decastar
# CLAY           4.92     60.15  301.5     2    8122    Decastar
# KARPOV         4.92     50.31  300.2     3    8099    Decastar
# BERNARD        5.32     62.77  280.1     4    8067    Decastar
# YURKOV         4.72     63.44  276.4     5    8036    Decastar
#
# affichage des dimensions du dataframe
# (41, 13)
#
# informations sur le dataframe
# ...

# %% [markdown]
# ### Question 2
# Stocker dans data_ACP les données sous forme **tableau numpy**, sans les trois dernières colonnes.

# %%
# Out:
#           100m  Long.jump  Shot.put  High.jump   400m  110m.hurdle  Discus  \
# SEBRLE   11.04       7.58     14.83       2.07  49.81        14.69   43.75
# CLAY     10.76       7.40     14.26       1.86  49.37        14.05   50.72
# KARPOV   11.02       7.30     14.77       2.04  48.37        14.09   48.95
# BERNARD  11.02       7.23     14.25       1.92  48.93        14.99   40.87
# YURKOV   11.34       7.09     15.19       2.10  50.42        15.31   46.26
#
#          Pole.vault  Javeline  1500m
# SEBRLE         5.02     63.19  291.7
# CLAY           4.92     60.15  301.5
# KARPOV         4.92     50.31  300.2
# BERNARD        5.32     62.77  280.1
# YURKOV         4.72     63.44  276.4
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Attention ici data_ACP est un dataframe pandas, or on veut travailler sur un tableau numpy

# %%
# Out:
# [[ 11.04   7.58  14.83   2.07  49.81  14.69  43.75   5.02  63.19 291.7 ]
#  [ 10.76   7.4   14.26   1.86  49.37  14.05  50.72   4.92  60.15 301.5 ]
#  [ 11.02   7.3   14.77   2.04  48.37  14.09  48.95   4.92  50.31 300.2 ]
#  [ 11.02   7.23  14.25   1.92  48.93  14.99  40.87   5.32  62.77 280.1 ]
#  [ 11.34   7.09  15.19   2.1   50.42  15.31  46.26   4.72  63.44 276.4 ]]
# <class 'numpy.ndarray'>

# %% [markdown]
# # ACP : pourcentage de variance expliquée
#
# ### Question 3
# Standardiser les données

# %%
# Out:
# [[ 0.16147779  1.02393687  0.43340505  1.06045671  0.16998066  0.18057156
#   -0.17252435  0.93798841  1.022196    1.09931561]
#  [-0.91629258  0.44797238 -0.26657256 -1.32973498 -0.21622224 -1.19281907
#    1.91655543  0.5738073   0.3845577   1.94927138]
#  [ 0.08449419  0.12799211  0.3597232   0.71900075 -1.0939561  -1.10698215
#    1.38604306  0.5738073  -1.67937681  1.83652215]
#  [ 0.08449419 -0.09599408 -0.27885287 -0.64682307 -0.60242514  0.82434841
#   -1.03573091  2.03053173  0.93410123  0.09324552]
#  [ 1.31623176 -0.54396646  0.87549618  1.40191267  0.70539831  1.51104373
#    0.57978415 -0.15455491  1.07463336 -0.22765615]]

# %% [markdown]
# ### Question 4
# Effectuer une ACP et afficher l'histogramme des valeurs propres.

# %% [markdown]
# ### Question 5
# Afficher la courbe du pourcentage de variance expliquée en fonction du nombre de composante gardée. Quel est le pourcentage de variance expliquée pour deux composantes ?

# %%
# Out:
# variance expliquée pour deux composantes
# 0.5

# %% [markdown]
# # ACP : représentation des individus
# ### Question 6
# Afficher les individus sur les 2 premières composantes.

# %% [markdown]
# ### Question 7
# Améliorer ce diagramme en prenant en compte la variable rang (classement de l'individu dans la compétition). Que constatez vous ?

# %% [markdown]
# # ACP : contribution des variables

# %% [markdown]
# ### Question 8
# Afficher les coordonnées des variables originales dans l'espace formé par les deux premières composantes principales. Quelle interprétation faites vous ? Citer deux variables tres corrélées entre elles. Citer deux variables semblant indépendantes. Quelles sont les variables les plus liées au premier axe.

# %%
# Out:
# (-0.7, 0.7)
